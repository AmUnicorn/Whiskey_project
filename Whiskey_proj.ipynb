# %%
import pandas as pd


data = pd.read_csv("C:/Users/thamm/Desktop/Whiskey_project/Dataset/whiskey.csv")

# %%
 data.sample()
# Out:
#                                             Name  Rating  Country Category  \
# 40  Bushmills 1608 Irish Whiskey Limited Edition    74.0  Ireland  Blended
#
#     Price   ABV  Age      Brand
# 40   90.0  46.0  NaN  Bushmills

# %%
data.describe()
# Out:
#            Rating       Price         ABV         Age
# count  272.000000  279.000000  270.000000  174.000000
# mean    84.474265   72.483871   44.610444   14.339080
# std     11.877887   83.992242    5.883056    6.322267
# min     40.000000    2.000000   35.500000    0.000000
# 25%     80.000000   30.000000   40.000000   10.000000
# 50%     88.000000   50.000000   43.000000   14.500000
# 75%     94.000000   80.000000   46.000000   18.000000
# max    100.000000  850.000000   68.200000   40.000000

# %%
Rating = len(data) - data['Rating'].count()
print("Missing value of rating = ", Rating)
# Out:
# Missing value of rating =  11

# %%
Price = len(data) - data['Price'].count()
print("Missing value of price = ", Price)
# Out:
# Missing value of price =  4

# %%
ABV = len(data) - data['ABV'].count()
print("Missing value of ABV = ", ABV)
# Out:
# Missing value of ABV =  13

# %%
Age = len(data) - data['Age'].count()
print("Missing value of age = ", Age)
# Out:
# Missing value of age =  109

# %%
 ##data = data.drop('Rating', 1)

# %%
data
# Out:
#                                                   Name  Rating   Country  \
# 0                      Canadian Hunter Canadian Whisky    40.0    Canada
# 1                Canadian LTD Blended Canadian Whiskey    43.0    Canada
# 2                                 Kellan Irish Whiskey    47.0   Ireland
# 3                          Rich & Rare Canadian Whisky    47.0    Canada
# 4                Canadian Mist Blended Canadian Whisky    48.0    Canada
# 5                           Slane Castle Irish Whiskey    50.0   Ireland
# 6             Canadian Club 6 Year Old Canadian Whisky    53.0    Canada
# 7                                Origine Irish Whiskey    54.0   Ireland
# 8                          Jack Daniel's No. 7 Whiskey    54.0       USA
# 9                            Ellington Canadian Whisky    54.0    Canada
# 10               Canadian Club Reserve Canadian Whisky    56.0    Canada
# 11                   Pendleton Blended Canadian Whisky    56.0    Canada
# 12                       Jim Beam Straight Rye Whiskey    57.0       USA
# 13        Catoctin Creek Organic Roundstone Rye Whisky    57.0       USA
# 14                     Johnnie Walker Red Label Whisky    58.0  Scotland
# 15   Danfield's Private Reserve Small Batch Canaida...    60.0    Canada
# 16                 Wiser's Small Batch Canadian Whisky    60.0    Canada
# 17                          8 Seconds Canadian Whiskey    64.0    Canada
# 18                                Feckin Irish Whiskey    64.0   Ireland
# 19                    Bushmills Original Irish Whiskey    65.0   Ireland
# 20                               Jameson Irish Whiskey    65.0   Ireland
# 21                               Templeton Rye Whiskey    67.0       USA
# 22           Dalwhinnie 15 Year Old Single Malt Scotch    67.0  Scotland
# 23   Forty Creek John K. Hall Small Batch Reserve W...    67.0    Canada
# 24                 Wiser's 18 Year Old Canadian Whisky    67.0    Canada
# 25               Black Velvet Reserve Canadian Whiskey    67.0    Canada
# 26                         Crown Royal Canadian Whisky    68.0    Canada
# 14       Blended   30.0  40.00   NaN     Johnnie Walker
# 15       Blended   25.0    NaN   NaN           Danfield
# 16           Rye   29.0  43.00   NaN            Wiser's
# 17       Blended   30.0  40.00   NaN          8 Seconds
# 18       Blended   20.0  40.00   NaN             Feckin
# 19       Blended   24.0  40.00   NaN          Bushmills
# 20       Blended   25.0  40.00   NaN            Jameson
# 21           Rye   35.0  40.00   4.0          Templeton
# 22     Highlands   50.0  43.00  15.0         Dalwhinnie
# 23       Blended   60.0  40.00   NaN        Forty Creek
# 24       Blended   65.0  40.00  18.0            Wiser's
# 25       Blended   14.0  40.00   8.0       Black Velvet
# 26       Blended   25.0  40.00   NaN        Crown Royal
# 27       Bourbon   12.0  40.00   NaN          Benchmark
# 28       Blended   23.0  40.00   NaN        Forty Creek
# 29       Blended   23.0  40.00  12.0      Canadian Club
# ..           ...    ...    ...   ...                ...
# 253    Highlands   80.0  46.00  10.0       Glenmorangie
# 254        Islay   92.0  46.30  18.0       Bunnahabhain
# 255        Islay  107.0  48.00  18.0          Laphroaig
# 256    Highlands   45.0  40.00  12.0             Cardhu
# 257     Speyside  100.0  43.00  18.0           Aberlour
# 258     Speyside   60.0  43.00  14.0           Balvenie
# 259        Islay   70.0  43.00   NaN           Caol Ila
# 260      Blended   50.0  40.00  17.0            Kingdom
# 261     Speyside   45.0  40.00  12.0           Balvenie
# 262    Highlands   45.0  48.00   NaN       Glen Garioch
# 263        Islay   70.0  43.00  15.0            Bowmore
# 264      Bourbon   11.0  40.00   NaN         Rebel Yell
# 265      Bourbon   58.0  53.50  15.0   Pappy Van Winkle
# 266          Rye   67.0  66.40   6.0    Thomas H. Handy
# 267        Islay   80.0  54.20   NaN             Ardbeg
# 268      Bourbon   60.0  57.15   NaN        Noah's Mill
# 269      Bourbon   80.0  62.00  15.0  Parker's Heritage
# 270  Single Malt   72.0  46.00  10.0         Tyrconnell
# 271    Highlands  165.0  43.00  18.0            Dalmore
# 272      Blended   92.0  43.00  12.0            Suntory
# 273      Blended    8.0    NaN   NaN            McAdams
# 274      Blended   22.0    NaN   4.0        Texas Crown
# 275        Islay  292.0  46.30  25.0       Bunnahabhain
# 276     Speyside   69.0  57.00  18.0          Glenlivet
# 277      Blended    NaN  43.00   NaN             Bell's
# 278    Highlands    NaN    NaN  10.0          Glengoyne
# 279      Blended   30.0  46.00  12.0          Tweeddale
# 280      Bourbon  280.0  45.00  16.0        A.H. Hirsch
# 281      Bourbon   40.0  45.00  18.0       Elijah Craig
# 282  Single Malt  100.0  59.20   NaN            Kavalan
#
# [283 rows x 8 columns]

# %%
data['Price'].mode()[0]
# Out:
# 50.0

# %%
data['ABV'].mean()
# Out:
# 44.61044444444445

# %%
data['Age'].mode()
# Out:
# 0    12.0
# dtype: float64

# %%
 data['Rating'] = data['Rating'].fillna(data['Rating'].mode()[0])

# %%
data['Price'] = data['Price'].fillna(data['Price'].mode()[0])

# %%
data['ABV'] =  data['ABV'].fillna(data['ABV'].mean())

# %%
# 258     Speyside   60.0  43.000000  14.0           Balvenie
# 259        Islay   70.0  43.000000  12.0           Caol Ila
# 260      Blended   50.0  40.000000  17.0            Kingdom
# 261     Speyside   45.0  40.000000  12.0           Balvenie
# 262    Highlands   45.0  48.000000  12.0       Glen Garioch
# 263        Islay   70.0  43.000000  15.0            Bowmore
# 264      Bourbon   11.0  40.000000  12.0         Rebel Yell
# 265      Bourbon   58.0  53.500000  15.0   Pappy Van Winkle
# 266          Rye   67.0  66.400000   6.0    Thomas H. Handy
# 267        Islay   80.0  54.200000  12.0             Ardbeg
# 268      Bourbon   60.0  57.150000  12.0        Noah's Mill
# 269      Bourbon   80.0  62.000000  15.0  Parker's Heritage
# 270  Single Malt   72.0  46.000000  10.0         Tyrconnell
# 271    Highlands  165.0  43.000000  18.0            Dalmore
# 272      Blended   92.0  43.000000  12.0            Suntory
# 273      Blended    8.0  44.610444  12.0            McAdams
# 274      Blended   22.0  44.610444   4.0        Texas Crown
# 275        Islay  292.0  46.300000  25.0       Bunnahabhain
# 276     Speyside   69.0  57.000000  18.0          Glenlivet
# 277      Blended   50.0  43.000000  12.0             Bell's
# 278    Highlands   50.0  44.610444  10.0          Glengoyne
# 279      Blended   30.0  46.000000  12.0          Tweeddale
# 280      Bourbon  280.0  45.000000  16.0        A.H. Hirsch
# 281      Bourbon   40.0  45.000000  18.0       Elijah Craig
# 282  Single Malt  100.0  59.200000  12.0            Kavalan
#
# [283 rows x 8 columns]

# %%
data.describe()
# Out:
#            Rating       Price         ABV         Age
# count  283.000000  283.000000  283.000000  283.000000
# mean    84.611307   72.166078   44.610444   13.438163
# std     11.663917   83.436798    5.745854    5.081488
# min     40.000000    2.000000   35.500000    0.000000
# 25%     81.000000   30.000000   40.000000   12.000000
# 50%     88.000000   50.000000   43.000000   12.000000
# 75%     93.000000   79.500000   46.000000   15.000000
# max    100.000000  850.000000   68.200000   40.000000

# %% [markdown]
# ## Task 3

# %% [markdown]
# #### – Investigate outlier(s): for each numeric attribute, perform IQR method to detect outlier.

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Rating    12.0
# Price     49.5
# ABV        6.0
# Age        3.0
# dtype: float64

# %%
data.shape
# Out:
# (283, 8)

# %% [markdown]
# #### Find the outlier using function
# #### The function return a boolean vector: True if the element is an outlier. False, otherwise.

# %%
import numpy as np   # to manipulate arrays

# a number "a" from the vector "x" is an outlier if 
# a > median(x)+1.5*iqr(x) or a < median-1.5*iqr(x)
# iqr: interquantile range = third interquantile - first interquantile
def outliers(x): 
       return np.abs(x- x.median()) > 1.5*(x.quantile(.75)-x.quantile(0.25))

# Give the outliers for the first column for example
outliers(data['Price'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# 270    False
# 271     True
# 272    False
# 273    False
# 274    False
# 275     True
# 276    False
# 277    False
# 278    False
# 279    False
# 280     True
# 281    False
# 282    False
# Name: Price, Length: 283, dtype: bool

# %%
outliers(data['ABV'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# 264    False
# 265     True
# 266     True
# 267     True
# 268     True
# 269     True
# 270    False
# 271    False
# 272    False
# 273    False
# 274    False
# 275    False
# 276     True
# 277    False
# 278    False
# 279    False
# 280    False
# 281    False
# 282     True
# Name: ABV, Length: 283, dtype: bool

# %%
outliers(data['Age'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 253    False
# 254     True
# 255     True
# 256    False
# 257     True
# 258    False
# 259    False
# 260     True
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# 266     True
# 267    False
# 268    False
# 269    False
# 270    False
# 271     True
# 272    False
# 273    False
# 274     True
# 275     True
# 276     True
# 277    False
# 278    False
# 279    False
# 280    False
# 281     True
# 282    False
# Name: Age, Length: 283, dtype: bool

# %% [markdown]
# ## Task 4

# %% [markdown]
# #### For each numeric attribute:
# #### 1. Plot histogram (explain your choice of bin size)
# ####                                                 2. Plot a box plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = data['Rating']
plt.hist(x, bins=20)
plt.ylabel('Rating of whiskey')
plt.show()

# %%
x = data['Price']
plt.hist(x, bins=20)
plt.ylabel('Price of whiskey')
plt.show()

# %%
x = data['ABV']
plt.hist(x, bins=20)
plt.ylabel('ABV of whiskey')
plt.show()

# %%
x = data['Age']
plt.hist(x, bins=20)
plt.ylabel('Age of whiskey')
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(x=data['Rating'])

# %%
sns.boxplot(x=data['Price'])

# %%
sns.boxplot(x=data['ABV'])

# %%
sns.boxplot(x=data['Age'])

# %% [markdown]
# #### For each nominal attribute: 1. Plot histogram count of frequency of each label

# %%
data['Name'].value_counts().plot(kind='bar')

# %%
data['Country'].value_counts().plot(kind='bar')

# %%
data['Category'].value_counts().plot(kind='bar')

# %%
data['Brand'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Task6 && Task7

# %%
data.dtypes
# Out:
# Name         object
# Rating      float64
# Country      object
# Category     object
# Price       float64
# ABV         float64
# Age         float64
# Brand        object
# dtype: object

# %%
from sklearn.decomposition import PCA

df = data[['Rating', 'Price',  'Age', 'ABV']]

pca = PCA(n_components=2, svd_solver='full')
pca.fit(df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
T = pca.transform(df)

# %%
# Started with 6 dimensions
df.shape
# Out:
# (283, 4)

# %%
# Left with 2 principle components
T.shape
# Out:
# (283, 2)

# %%
df.head()
# Out:
#    Rating  Price   Age        ABV
# 0    40.0    9.0  12.0  40.000000
# 1    43.0   10.0  12.0  44.610444
# 2    47.0   20.0  12.0  40.000000
# 3    47.0   10.0  12.0  44.610444
# 4    48.0   12.0  12.0  40.000000

# %%
T
# Out:
# array([[-6.48736887e+01,  4.22503840e+01],
#        [-3.66347845e+01, -1.50450423e+01],
#        [ 4.84771414e+01, -1.22739979e+01],
#        [-2.97164513e+01, -1.46743982e+01],
#        [ 8.26161014e+00, -1.39511535e+01],
#        [ 2.05337066e+01, -1.38554574e+01],
#        [ 3.55215491e+01, -1.34791925e+01],
#        [-2.66488196e+01, -1.46402889e+01],
#        [ 2.85052115e+01, -1.30835047e+01],
#        [-1.15823327e+01, -1.45278847e+01],
#        [-1.66820992e+00, -1.40358146e+01],
#        [-2.14762316e+01, -1.46562042e+01],
#        [-2.66488196e+01, -1.46402889e+01],
#        [-2.66069601e+01, -1.57267133e+01],
#        [-1.56044663e+00, -1.41667897e+01],
#        [-6.06011004e+01, -1.60164505e+01],
#        [-1.34886640e+01, -1.60784258e+01],
#        [-4.75708699e+00, -1.70730815e+01],
#        [ 8.37635830e+00, -1.51520553e+01],
#        [-1.15801359e+01, -1.63621810e+01],
#        [ 8.52493459e+00, -1.63422942e+01],
#        [ 3.11404205e-01, -1.52639018e+01],
#        [ 9.34525496e+01, -1.14415531e+01],
#        [ 1.98766867e+01, -2.26695646e+00],
#        [-6.39969923e+01, -5.88558827e+00],
#        [-5.03040101e+01, -4.96966644e+00],
#        [ 2.20080227e+02,  4.81240248e+00],
#        [-2.80225198e+00, -5.36108220e+00],
#        [-2.20643661e+01, -3.96692074e+00],
#        [-2.21277817e+01, -4.09830723e+00],
#        [-4.20205986e+01, -5.18383667e+00],
#        [ 2.07766977e+02,  4.89616781e+00],
#        [-3.18243395e+01, -4.90523053e+00],
#        [ 2.79502241e+01, -4.14316306e+00]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.97547291, 0.01787219])

# %%
components = pd.DataFrame(pca.components_, columns = df.columns, index=[1, 2])
components
# Out:
#      Rating     Price       Age       ABV
# 1  0.038566  0.998596  0.035921  0.005232
# 2 -0.988946  0.040475 -0.043658 -0.135803

# %%
import math

def get_important_features(transformed_features, components_, columns):
    """
    This function will return the most "important" 
    features so we can determine which have the most
    effect on multi-dimensional scaling
    """
    num_columns = len(columns)

    # Scale the principal components by the max value in
    # the transformed set belonging to that component
    xvector = components_[0] * max(transformed_features[:,0])
    yvector = components_[1] * max(transformed_features[:,1])

    # Sort each column by it's length. These are your *original*
    # columns, not the principal components.
    important_features = { columns[i] : math.sqrt(xvector[i]**2 + yvector[i]**2) for i in range(num_columns) }
    important_features = sorted(zip(important_features.values(), important_features.keys()), reverse=True)
    print( "Features by importance:\n", important_features)

get_important_features(T, pca.components_, df.columns.values)
# Out:
# Features by importance:
#  [(776.3701237438903, 'Price'), (51.428180626750674, 'Rating'), (27.988045719263262, 'Age'), (7.033507649768691, 'ABV')]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def draw_vectors(transformed_features, components_, columns):
    """
    This funtion will project your *original* features
    onto your principal component feature-space, so that you can
    visualize how "important" each one was in the
    multi-dimensional scaling
    """

    num_columns = len(columns)

    # Scale the principal components by the max value in
    # the transformed set belonging to that component
    xvector = components_[0] * max(transformed_features[:,0])
    yvector = components_[1] * max(transformed_features[:,1])

    ax = plt.axes()

    for i in range(num_columns):
    # Use an arrow to project each original feature as a
    # labeled vector on your principal component axes
        plt.arrow(0, 0, xvector[i], yvector[i], color='b', width=0.0005, head_width=0.02, alpha=0.75)
        plt.text(xvector[i]*1.2, yvector[i]*1.2, list(columns)[i], color='b', alpha=0.75)

    return ax

# %%
ax = draw_vectors(T, pca.components_, df.columns.values)
T_df = pd.DataFrame(T)
T_df.columns = ['component1', 'component2']

T_df['color'] = 'y'
T_df.loc[T_df['component1'] > 125, 'color'] = 'g'
T_df.loc[T_df['component2'] > 125, 'color'] = 'r'

plt.xlabel('Principle Component 1')
plt.ylabel('Principle Component 2')
plt.scatter(T_df['component1'], T_df['component2'], color=T_df['color'], alpha=0.5)
plt.show()

# %%
def change_Labels(x):
    
    if x>=40 and x<=60:
        return 'Low'
    if x>=61 and x<=80:
        return 'Medium'
    if x>=81 and x<=100:
        return 'High'

# %%
data['Rating'] = data['Rating'].apply(change_Labels)

# %%
data
# Out:
#                                                   Name  Rating   Country  \
# 0                      Canadian Hunter Canadian Whisky    40.0    Canada
# 1                Canadian LTD Blended Canadian Whiskey    43.0    Canada
# 2                                 Kellan Irish Whiskey    47.0   Ireland
# 3                          Rich & Rare Canadian Whisky    47.0    Canada
# 4                Canadian Mist Blended Canadian Whisky    48.0    Canada
# 5                           Slane Castle Irish Whiskey    50.0   Ireland
# 6             Canadian Club 6 Year Old Canadian Whisky    53.0    Canada
# 7                                Origine Irish Whiskey    54.0   Ireland
# 8                          Jack Daniel's No. 7 Whiskey    54.0       USA
# 9                            Ellington Canadian Whisky    54.0    Canada
# 10               Canadian Club Reserve Canadian Whisky    56.0    Canada
# 11                   Pendleton Blended Canadian Whisky    56.0    Canada
# 12                       Jim Beam Straight Rye Whiskey    57.0       USA
# 13        Catoctin Creek Organic Roundstone Rye Whisky    57.0       USA
# 14                     Johnnie Walker Red Label Whisky    58.0  Scotland
# 15   Danfield's Private Reserve Small Batch Canaida...    60.0    Canada
# 16                 Wiser's Small Batch Canadian Whisky    60.0    Canada
# 17                          8 Seconds Canadian Whiskey    64.0    Canada
# 18                                Feckin Irish Whiskey    64.0   Ireland
# 19                    Bushmills Original Irish Whiskey    65.0   Ireland
# 20                               Jameson Irish Whiskey    65.0   Ireland
# 21                               Templeton Rye Whiskey    67.0       USA
# 22           Dalwhinnie 15 Year Old Single Malt Scotch    67.0  Scotland
# 23   Forty Creek John K. Hall Small Batch Reserve W...    67.0    Canada
# 24                 Wiser's 18 Year Old Canadian Whisky    67.0    Canada
# 25               Black Velvet Reserve Canadian Whiskey    67.0    Canada
# 26                         Crown Royal Canadian Whisky    68.0    Canada
# 27   Benchmark Old No. 8 Kentucky Straight Bourbon ...    68.0       USA
# 28          Forty Creek Barrel Select Canadian Whiskey    69.0    Canada
# 29            Canadian Club Classic 12 Canadian Whisky    69.0    Canada
# ..                                                 ...     ...       ...
# 253                    Glenmorangie Single Malt Scotch    99.0  Scotland
# 20       Blended   25.0  40.000000  12.0            Jameson
# 21           Rye   35.0  40.000000   4.0          Templeton
# 22     Highlands   50.0  43.000000  15.0         Dalwhinnie
# 23       Blended   60.0  40.000000  12.0        Forty Creek
# 24       Blended   65.0  40.000000  18.0            Wiser's
# 25       Blended   14.0  40.000000   8.0       Black Velvet
# 26       Blended   25.0  40.000000  12.0        Crown Royal
# 27       Bourbon   12.0  40.000000  12.0          Benchmark
# 28       Blended   23.0  40.000000  12.0        Forty Creek
# 29       Blended   23.0  40.000000  12.0      Canadian Club
# ..           ...    ...        ...   ...                ...
# 253    Highlands   80.0  46.000000  10.0       Glenmorangie
# 254        Islay   92.0  46.300000  18.0       Bunnahabhain
# 255        Islay  107.0  48.000000  18.0          Laphroaig
# 256    Highlands   45.0  40.000000  12.0             Cardhu
# 257     Speyside  100.0  43.000000  18.0           Aberlour
# 258     Speyside   60.0  43.000000  14.0           Balvenie
# 259        Islay   70.0  43.000000  12.0           Caol Ila
# 260      Blended   50.0  40.000000  17.0            Kingdom
# 261     Speyside   45.0  40.000000  12.0           Balvenie
# 262    Highlands   45.0  48.000000  12.0       Glen Garioch
# 263        Islay   70.0  43.000000  15.0            Bowmore
# 264      Bourbon   11.0  40.000000  12.0         Rebel Yell
# 265      Bourbon   58.0  53.500000  15.0   Pappy Van Winkle
# 266          Rye   67.0  66.400000   6.0    Thomas H. Handy
# 267        Islay   80.0  54.200000  12.0             Ardbeg
# 268      Bourbon   60.0  57.150000  12.0        Noah's Mill
# 269      Bourbon   80.0  62.000000  15.0  Parker's Heritage
# 270  Single Malt   72.0  46.000000  10.0         Tyrconnell
# 271    Highlands  165.0  43.000000  18.0            Dalmore
# 272      Blended   92.0  43.000000  12.0            Suntory
# 273      Blended    8.0  44.610444  12.0            McAdams
# 274      Blended   22.0  44.610444   4.0        Texas Crown
# 275        Islay  292.0  46.300000  25.0       Bunnahabhain
# 276     Speyside   69.0  57.000000  18.0          Glenlivet
# 277      Blended   50.0  43.000000  12.0             Bell's
# 278    Highlands   50.0  44.610444  10.0          Glengoyne
# 279      Blended   30.0  46.000000  12.0          Tweeddale
# 280      Bourbon  280.0  45.000000  16.0        A.H. Hirsch
# 281      Bourbon   40.0  45.000000  18.0       Elijah Craig
# 282  Single Malt  100.0  59.200000  12.0            Kavalan
#
# [283 rows x 8 columns]

# %% [markdown]
# ### PCA

# %%
data['Rating'].value_counts()
# Out:
# High      213
# Medium     53
# Low        17
# Name: Rating, dtype: int64

# %%
data.corr()
# Out:
#           Price       ABV       Age
# Price  1.000000  0.074832  0.588755
# ABV    0.074832  1.000000 -0.029453
# Age    0.588755 -0.029453  1.000000

# %% [markdown]
# ## C4.5

# %% [markdown]
# ### split data into test and train

# %%
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
# Out:
# C:\Users\thamm\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print( "Dataset Lenght:: ", len(data))
print( "Dataset Shape:: ", data.shape)
# Out:
# Dataset Lenght::  283
# Dataset Shape::  (283, 8)

# %%
data.head()
# Out:
#                                     Name Rating  Country Category  Price  \
# 0        Canadian Hunter Canadian Whisky    Low   Canada  Blended    9.0
# 1  Canadian LTD Blended Canadian Whiskey    Low   Canada  Blended   10.0
# 2                   Kellan Irish Whiskey    Low  Ireland  Blended   20.0
# 3            Rich & Rare Canadian Whisky    Low   Canada  Blended   10.0
# 4  Canadian Mist Blended Canadian Whisky    Low   Canada  Blended   12.0
#
#          ABV   Age            Brand
# 0  40.000000  12.0  Canadian Hunter
# 1  44.610444  12.0     Canadian LTD
# 2  40.000000  12.0           Kellan
# 3  44.610444  12.0      Rich & Rare
# 4  40.000000  12.0    Canadian Mist

# %%
X = data.values[:, 4:6]
Y = data.Rating

# %%
X
# Out:
# array([[9.0, 40.0],
#        [10.0, 44.61044444444445],
#        [20.0, 40.0],
#        [10.0, 44.61044444444445],
#        [12.0, 40.0],
#        [25.0, 44.61044444444445],
#        [12.0, 40.0],
#        [17.0, 44.61044444444445],
#        [20.0, 40.0],
#        [11.0, 44.61044444444445],
#        [16.0, 44.61044444444445],
#        [26.0, 40.0],
#        [15.0, 51.0],
#        [38.0, 40.0],
#        [30.0, 40.0],
#        [25.0, 44.61044444444445],
#        [29.0, 43.0],
#        [30.0, 40.0],
#        [20.0, 40.0],
#        [24.0, 40.0],
#        [25.0, 40.0],
#        [35.0, 40.0],
#        [50.0, 43.0],
#        [60.0, 40.0],
#        [65.0, 40.0],
#        [14.0, 40.0],
#        [25.0, 40.0],
#        [12.0, 40.0],
#        [23.0, 40.0],
#        [23.0, 40.0],
#        [15.0, 40.0],
#        [27.0, 45.0],
#        [20.0, 40.0],
#        [45.0, 43.0],
#        [26.0, 40.0],
#        [27.0, 40.0],
#        [50.0, 43.0],
#        [48.0, 46.0],
#        [84.0, 40.0],
#        [90.0, 40.0],
#        [90.0, 46.0],
#        [40.0, 40.0],
#        [50.0, 45.0],
#        [58.0, 40.0],
#        [85.0, 43.0],
#        [46.0, 45.0],
#        [38.0, 53.0],
#        [36.0, 46.0],
#        [70.0, 46.0],
#        [16.0, 40.0],
#        [45.0, 40.0],
#        [50.0, 43.0],
#        [28.0, 40.0],
#        [70.0, 46.0],
#        [179.0, 43.0],
#        [20.0, 50.0],
#        [75.0, 45.0],
#        [17.0, 40.0],
#        [73.0, 40.0],
#        [65.0, 58.0],
#        [32.0, 40.0],
#        [41.0, 46.0],
#        [26.0, 43.0],
#        [27.0, 40.0],
#        [16.0, 43.0],
#        [63.0, 43.0],
#        [25.0, 43.0],
#        [60.0, 62.0],
#        [85.0, 62.8],
#        [36.0, 40.0],
#        [20.0, 40.0],
#        [43.0, 46.0],
#        [58.0, 43.0],
#        [20.0, 40.0],
#        [35.0, 42.5],
#        [100.0, 58.2],
#        [25.0, 40.0],
#        [40.0, 40.0],
#        [60.0, 42.0],
#        [55.0, 41.0],
#        [18.0, 40.0],
#        [17.0, 35.5],
#        [69.0, 40.0],
#        [25.0, 40.0],
#        [17.0, 41.0],
#        [50.0, 40.0],
#        [28.0, 40.0],
#        [19.0, 43.0],
#        [16.0, 62.5],
#        [50.0, 40.0],
#        [70.0, 40.0],
#        [100.0, 43.0],
#        [19.0, 50.0],
#        [17.0, 40.0],
#        [133.0, 53.0],
#        [100.0, 43.0],
#        [28.0, 46.0],
#        [33.0, 44.61044444444445],
#        [246.0, 40.0],
#        [42.0, 46.0],
#        [70.0, 45.0],
#        [35.0, 47.0],
#        [65.0, 43.0],
#        [60.0, 43.0],
#        [25.0, 40.0],
#        [47.0, 40.0],
#        [199.0, 40.0],
#        [100.0, 40.0],
#        [43.0, 40.0],
#        [160.0, 43.0],
#        [34.0, 46.0],
#        [68.0, 43.0],
#        [98.0, 54.7],
#        [65.0, 50.0],
#        [100.0, 47.5],
#        [39.0, 40.0],
#        [95.0, 46.0],
#        [36.0, 40.0],
#        [61.0, 40.0],
#        [24.0, 40.0],
#        [50.0, 40.0],
#        [43.0, 43.0],
#        [43.0, 43.0],
#        [20.0, 43.0],
#        [24.0, 45.0],
#        [40.0, 40.0],
#        [49.0, 47.8],
#        [20.0, 45.0],
#        [50.0, 40.0],
#        [30.0, 45.0],
#        [60.0, 44.61044444444445],
#        [50.0, 43.0],
#        [49.0, 47.0],
#        [53.0, 50.0],
#        [40.0, 45.0],
#        [27.0, 45.0],
#        [59.0, 63.0],
#        [75.0, 58.0],
#        [32.0, 40.0],
#        [60.0, 40.0],
#        [100.0, 43.0],
#        [35.0, 40.0],
#        [30.0, 40.0],
#        [220.0, 58.3],
#        [117.0, 58.7],
#        [48.0, 43.0],
#        [40.0, 40.0],
#        [45.0, 46.0],
#        [25.0, 42.0],
#        [48.0, 40.0],
#        [28.0, 50.0],
#        [40.0, 40.0],
#        [850.0, 43.0],
#        [61.0, 46.0],
#        [37.0, 60.0],
#        [39.0, 43.0],
#        [75.0, 47.0],
#        [21.0, 50.0],
#        [53.0, 43.0],
#        [128.0, 43.0],
#        [27.0, 45.0],
#        [34.0, 45.0],
#        [50.0, 47.0],
#        [125.0, 50.0],
#        [65.0, 43.0],
#        [35.0, 40.0],
#        [2.0, 44.61044444444445],
#        [250.0, 42.0],
#        [260.0, 40.0],
#        [90.0, 47.0],
#        [305.0, 43.0],
#        [256.0, 46.0],
#        [240.0, 48.1],
#        [140.0, 40.0],
#        [63.0, 59.5],
#        [79.0, 43.0],
#        [70.0, 43.0],
#        [45.0, 43.0],
#        [37.0, 54.1],
#        [70.0, 43.0],
#        [55.0, 40.0],
#        [90.0, 47.0],
#        [29.0, 43.0],
#        [64.0, 40.0],
#        [132.0, 40.0],
#        [75.0, 46.0],
#        [400.0, 43.0],
#        [120.0, 40.0],
#        [50.0, 61.8],
#        [67.0, 46.0],
#        [94.0, 46.0],
#        [70.0, 40.0],
#        [40.0, 40.0],
#        [47.0, 46.3],
#        [45.0, 40.0],
#        [57.0, 45.0],
#        [109.0, 43.0],
#        [47.0, 48.0],
#        [39.0, 40.0],
#        [133.0, 40.0],
#        [35.0, 45.0],
#        [32.0, 45.0],
#        [108.0, 46.3],
#        [107.0, 43.0],
#        [60.0, 46.0],
#        [93.0, 45.2],
#        [95.0, 40.0],
#        [70.0, 68.2],
#        [140.0, 44.0],
#        [175.0, 40.0],
#        [115.0, 46.0],
#        [150.0, 40.0],
#        [68.0, 45.82],
#        [80.0, 43.0],
#        [190.0, 43.0],
#        [45.0, 43.0],
#        [42.0, 50.5],
#        [120.0, 46.0],
#        [47.0, 40.0],
#        [55.0, 46.0],
#        [220.0, 43.0],
#        [70.0, 45.0],
#        [80.0, 63.0],
#        [50.0, 50.05],
#        [80.0, 46.2],
#        [300.0, 56.5],
#        [365.0, 48.1],
#        [84.0, 46.0],
#        [65.0, 50.0],
#        [30.0, 47.5],
#        [43.0, 40.0],
#        [89.0, 43.0],
#        [400.0, 44.0],
#        [62.0, 46.0],
#        [73.0, 43.0],
#        [30.0, 40.0],
#        [79.0, 43.0],
#        [43.0, 46.3],
#        [54.0, 40.0],
#        [90.0, 57.8],
#        [48.0, 43.0],
#        [580.0, 43.0],
#        [25.0, 40.0],
#        [30.0, 40.0],
#        [65.0, 65.0],
#        [40.0, 40.0],
#        [65.0, 48.0],
#        [64.0, 40.0],
#        [40.0, 46.0],
#        [123.0, 40.0],
#        [35.0, 40.0],
#        [120.0, 43.0],
#        [42.0, 40.0],
#        [80.0, 46.0],
#        [92.0, 46.3],
#        [107.0, 48.0],
#        [45.0, 40.0],
#        [100.0, 43.0],
#        [60.0, 43.0],
#        [70.0, 43.0],
#        [50.0, 40.0],
#        [45.0, 40.0],
#        [45.0, 48.0],
#        [70.0, 43.0],
#        [11.0, 40.0],
#        [58.0, 53.5],
#        [67.0, 66.4],
#        [80.0, 54.2],
#        [60.0, 57.15],
#        [80.0, 62.0],
#        [72.0, 46.0],
#        [165.0, 43.0],
#        [92.0, 43.0],
#        [8.0, 44.61044444444445],
#        [22.0, 44.61044444444445],
#        [292.0, 46.3],
#        [69.0, 57.0],
#        [50.0, 43.0],
#        [50.0, 44.61044444444445],
#        [30.0, 46.0],
#        [280.0, 45.0],
#        [40.0, 45.0],
#        [100.0, 59.2]], dtype=object)

# %%
Y
# Out:
# 0         Low
# 1         Low
# 2         Low
# 3         Low
# 4         Low
# 5         Low
# 6         Low
# 7         Low
# 8         Low
# 9         Low
# 10        Low
# 11        Low
# 12        Low
# 13        Low
# 14        Low
# 15        Low
# 16        Low
# 17     Medium
# 18     Medium
# 19     Medium
# 20     Medium
# 21     Medium
# 22     Medium
# 23     Medium
# 24     Medium
# 25     Medium
# 26     Medium
# 27     Medium
# 28     Medium
# 29     Medium
#         ...
# 253      High
# 254      High
# 255      High
# 256      High
# 257      High
# 258      High
# 259      High
# 260      High
# 261      High
# 262      High
# 263      High
# 264      High
# 265      High
# 266      High
# 267      High
# 268      High
# 269      High
# 270      High
# 271      High
# 272      High
# 273      High
# 274      High
# 275      High
# 276      High
# 277      High
# 278      High
# 279      High
# 280      High
# 281      High
# 282      High
# Name: Rating, Length: 283, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.2, random_state = 100)

# %% [markdown]
# ### Decision Tree Classifier with criterion gini index

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                               max_depth=3, min_samples_leaf=5)
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
y_pred = clf_gini.predict(X_test)
y_pred
# Out:
# array(['High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'Low', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'Low',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'Medium',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'Low',
#        'High'], dtype=object)

# %%
print( "Accuracy is ", accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy is  77.19298245614034

# %%
from sklearn.metrics import confusion_matrix
y_actu = y_test
y_pred = y_pred
confusion_matrix(y_actu, y_pred)
# Out:
# array([[43,  1,  1],
#        [ 1,  1,  0],
#        [ 9,  1,  0]], dtype=int64)

# %%
df_confusion = pd.crosstab(y_actu, y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  High  Low  Medium  All
# Actual
# High         43    1       1   45
# Low           1    1       0    2
# Medium        9    1       0   10
# All          53    3       1   57

# %% [markdown]
# ### Decision Tree Classifier with criterion information gain

# %%
clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100,
 max_depth=3, min_samples_leaf=5)
clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
y_pred_en = clf_entropy.predict(X_test)
y_pred_en
# Out:
# array(['High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'Low', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'Low',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'Medium',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'Low',
#        'High'], dtype=object)

# %%
print( "Accuracy is ", accuracy_score(y_test,y_pred_en)*100)
# Out:
# Accuracy is  77.19298245614034

# %%
y_actu = y_test
y_pred = y_pred_en
confusion_matrix(y_actu, y_pred)
# Out:
# array([[43,  1,  1],
#        [ 1,  1,  0],
#        [ 9,  1,  0]], dtype=int64)

# %%
df_confusion = pd.crosstab(y_actu, y_pred_en, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  High  Low  Medium  All
# Actual
# High         43    1       1   45
# Low           1    1       0    2
# Medium        9    1       0   10
# All          53    3       1   57
